# %% [markdown]
# # EDA_Kepler

# %%
# Importations
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Configuration
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# 1. CHARGEMENT DES DONNÉES
df = pd.read_csv('C:/Users/chaym/Desktop/NasaChallenge/data/processed/Kepler_filtered.csv')

print("APERÇU DU DATASET")
print(f"Shape: {df.shape}")
print(f"\nPremières lignes:")
print(df.head())

# 2. INFORMATIONS GÉNÉRALES
print("\nINFO")
print(df.info())

print("\nSTATISTIQUES")
print(df.describe())

# 3. DISTRIBUTION DE LA TARGET
print("\nDISTRIBUTION DE koi_disposition")
print(df['koi_disposition'].value_counts())
print("\nPourcentages:")
print(df['koi_disposition'].value_counts(normalize=True) * 100)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
df['koi_disposition'].value_counts().plot(kind='bar', color=['green', 'red', 'orange'])
plt.title('Distribution des classes')
plt.ylabel('Nombre')

plt.subplot(1, 2, 2)
df['koi_disposition'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Répartition en %')
plt.ylabel('')
plt.tight_layout()
plt.show()

# 4. VALEURS MANQUANTES
print("\nVALEURS MANQUANTES")
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing': missing,
    'Percentage': missing_pct
}).sort_values('Missing', ascending=False)
print(missing_df[missing_df['Missing'] > 0])

# Visualisation
plt.figure(figsize=(12, 6))
missing_df[missing_df['Missing'] > 0].plot(kind='barh', y='Percentage')
plt.title('Pourcentage de valeurs manquantes')
plt.xlabel('Pourcentage (%)')
plt.show()
# Out:
# APERÇU DU DATASET
# Shape: (9564, 19)
#
# Premières lignes:
#       kepid kepoi_name koi_disposition  koi_period  koi_period_err1  \
# 0  10797460  K00752.01       CONFIRMED    9.488036     2.775000e-05
# 1  10797460  K00752.02       CONFIRMED   54.418383     2.479000e-04
# 2  10811496  K00753.01       CANDIDATE   19.899140     1.494000e-05
# 3  10848459  K00754.01  FALSE POSITIVE    1.736952     2.630000e-07
# 4  10854555  K00755.01       CONFIRMED    2.525592     3.761000e-06
#
#    koi_period_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0    -2.775000e-05       2.95750            0.08190           -0.08190
# 1    -2.479000e-04       4.50700            0.11600           -0.11600
# 2    -1.494000e-05       1.78220            0.03410           -0.03410
# 3    -2.630000e-07       2.40641            0.00537           -0.00537
# 4    -3.761000e-06       1.65450            0.04200           -0.04200
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      615.8            19.5           -19.5      2.26           0.26
# 1      874.8            35.5           -35.5      2.83           0.32
# 2    10829.0           171.0          -171.0     14.60           3.92
# 3     8079.2            12.8           -12.8     33.46           8.50
# 4      603.3            16.9           -16.9      2.75           0.88
#
#    koi_prad_err2  koi_srad  koi_srad_err1  koi_srad_err2  koi_model_snr
# 0          -0.15     0.927          0.105         -0.061           35.8
# 1          -0.19     0.927          0.105         -0.061           25.8
# 2          -1.31     0.868          0.233         -0.078           76.3
# 3          -2.83     0.791          0.201         -0.067          505.6
# 4          -0.35     1.046          0.334         -0.133           40.9
#
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   koi_disposition    9564 non-null   object
#  3   koi_period         9564 non-null   float64
#  4   koi_period_err1    9110 non-null   float64
#  5   koi_period_err2    9110 non-null   float64
#  6   koi_duration       9564 non-null   float64
#  7   koi_duration_err1  9110 non-null   float64
#  8   koi_duration_err2  9110 non-null   float64
#  9   koi_depth          9201 non-null   float64
#  10  koi_depth_err1     9110 non-null   float64
#  11  koi_depth_err2     9110 non-null   float64
#  12  koi_prad           9201 non-null   float64
#  13  koi_prad_err1      9201 non-null   float64
#  14  koi_prad_err2      9201 non-null   float64
#  15  koi_srad           9201 non-null   float64
#  16  koi_srad_err1      9096 non-null   float64
#  17  koi_srad_err2      9096 non-null   float64
#  18  koi_model_snr      9201 non-null   float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 1.4+ MB
# None
#
# STATISTIQUES
#               kepid     koi_period  koi_period_err1  koi_period_err2  \
# count  9.564000e+03    9564.000000      9110.000000      9110.000000
# mean   7.690628e+06      75.671358         0.002148        -0.002148
# std    2.653459e+06    1334.744046         0.008236         0.008236
# min    7.574500e+05       0.241843         0.000000        -0.172500
# 25%    5.556034e+06       2.733684         0.000005        -0.000276
# 50%    7.906892e+06       9.752831         0.000035        -0.000035
# 75%    9.873066e+06      40.715178         0.000276        -0.000005
# max    1.293514e+07  129995.778400         0.172500         0.000000
#
#        koi_duration  koi_duration_err1  koi_duration_err2     koi_depth  \
# count   9564.000000        9110.000000        9110.000000  9.201000e+03
# mean       5.621606           0.339942          -0.339942  2.379134e+04
# std        6.471554           0.669823           0.669823  8.224268e+04
# min        0.052000           0.000000         -20.200000  0.000000e+00
# 25%        2.437750           0.050800          -0.350000  1.599000e+02
# 50%        3.792600           0.142000          -0.142000  4.211000e+02
# 75%        6.276500           0.350000          -0.050800  1.473400e+03
# max      138.540000          20.200000           0.000000  1.541400e+06
#
#        koi_depth_err1  koi_depth_err2       koi_prad  koi_prad_err1  \
# count     9110.000000     9110.000000    9201.000000    9201.000000
# mean       123.197563     -123.197563     102.891778      17.657684
# std       4112.615230     4112.615230    3077.639126     391.138501
# min          0.000000  -388600.000000       0.080000       0.000000
# 25%          9.600000      -49.500000       1.400000       0.230000
# 50%         20.750000      -20.750000       2.390000       0.520000
# 75%         49.500000       -9.600000      14.930000       2.320000
# max     388600.000000        0.000000  200346.000000   21640.000000
#
#        koi_prad_err2     koi_srad  koi_srad_err1  koi_srad_err2  koi_model_snr
# count    9201.000000  9201.000000    9096.000000    9096.000000    9201.000000
# mean      -33.023314     1.728712       0.362292      -0.394806     259.895001
# std      1193.519910     6.127185       0.930870       2.168213     795.806615
# min    -77180.000000     0.109000       0.000000    -116.137000       0.000000
# 25%        -1.940000     0.829000       0.129000      -0.250000      12.000000
# 50%        -0.300000     1.000000       0.251000      -0.111000      23.000000
# 75%        -0.140000     1.345000       0.364000      -0.069000      78.000000
# max         0.000000   229.908000      33.091000       0.000000    9054.700000
#
# DISTRIBUTION DE koi_disposition
# koi_disposition
# FALSE POSITIVE    4839
# CONFIRMED         2746
# CANDIDATE         1979
# Name: count, dtype: int64
#
# Pourcentages:
# koi_disposition
# FALSE POSITIVE    50.595985
# CONFIRMED         28.711836
# CANDIDATE         20.692179
# Name: proportion, dtype: float64
# VALEURS MANQUANTES
#                    Missing  Percentage
# koi_srad_err1          468    4.893350
# koi_srad_err2          468    4.893350
# koi_period_err1        454    4.746968
# koi_depth_err1         454    4.746968
# koi_depth_err2         454    4.746968
# koi_duration_err2      454    4.746968
# koi_period_err2        454    4.746968
# koi_duration_err1      454    4.746968
# koi_prad_err2          363    3.795483
# koi_depth              363    3.795483
# koi_prad_err1          363    3.795483
# koi_srad               363    3.795483
# koi_model_snr          363    3.795483
# koi_prad               363    3.795483
